# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading the DataSet

# %%
df = pd.read_csv('./DataSets/BostonHousing.csv')

df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %% [markdown]
# ## Data Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       501 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
df.isna().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         5
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
df.dropna(inplace=True)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 501 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     501 non-null    float64
#  1   zn       501 non-null    float64
#  2   indus    501 non-null    float64
#  3   chas     501 non-null    int64
#  4   nox      501 non-null    float64
#  5   rm       501 non-null    float64
#  6   age      501 non-null    float64
#  7   dis      501 non-null    float64
#  8   rad      501 non-null    int64
#  9   tax      501 non-null    int64
#  10  ptratio  501 non-null    float64
#  11  b        501 non-null    float64
#  12  lstat    501 non-null    float64
#  13  medv     501 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 58.7 KB

# %%
plt.figure(figsize=(12,12))
plt.subplot(4,4,1)
sns.boxplot(x = df["crim"])
plt.subplot(4,4,2)
sns.boxplot(x = df["zn"])
plt.subplot(4,4,3)
sns.boxplot(x = df["indus"])
plt.subplot(4,4,4)
sns.boxplot(x = df["chas"])
plt.subplot(4,4,5)
sns.boxplot(x = df["nox"])
plt.subplot(4,4,6)
sns.boxplot(x = df["rm"])
plt.subplot(4,4,7)
sns.boxplot(x = df["age"])
plt.subplot(4,4,8)
sns.boxplot(x = df["dis"])
plt.subplot(4,4,9)
sns.boxplot(x = df["rad"])
plt.subplot(4,4,10)
sns.boxplot(x = df["tax"])
plt.subplot(4,4,11)
sns.boxplot(x = df["ptratio"])
plt.subplot(4,4,12)
sns.boxplot(x = df["b"])
plt.subplot(4,4,13)
sns.boxplot(x = df["lstat"])
plt.show()

# %%
df["chas"].value_counts()
# Out:
# chas
# 0    466
# 1     35
# Name: count, dtype: int64

# %%
df.corr()
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.201470  0.407544 -0.057032  0.420611 -0.219433  0.354739
# zn      -0.201470  1.000000 -0.536624 -0.043209 -0.518108  0.311173 -0.569695
# indus    0.407544 -0.536624  1.000000  0.062351  0.762937 -0.394193  0.646157
# chas    -0.057032 -0.043209  0.062351  1.000000  0.090371  0.091468  0.087384
# nox      0.420611 -0.518108  0.762937  0.090371  1.000000 -0.302751  0.732899
# rm      -0.219433  0.311173 -0.394193  0.091468 -0.302751  1.000000 -0.240286
# age      0.354739 -0.569695  0.646157  0.087384  0.732899 -0.240286  1.000000
# dis     -0.380572  0.665634 -0.709741 -0.098696 -0.771108  0.203507 -0.751500
# rad      0.624932 -0.314530  0.597721 -0.008872  0.611942 -0.210718  0.460090
# tax      0.582243 -0.315991  0.720800 -0.037146  0.666959 -0.292794  0.508338
# ptratio  0.291731 -0.392956  0.382633 -0.121830  0.188830 -0.357612  0.264496
# ...

# %% [markdown]
# "chas" has least significance on medv so remove it

# %%
df = df.drop(["chas"], axis=1)

df.head()
# Out:
#       crim    zn  indus    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df.describe()
# Out:
#              crim          zn       indus         nox          rm         age  \
# count  501.000000  501.000000  501.000000  501.000000  501.000000  501.000000
# mean     3.647414   11.402196   11.160619    0.555151    6.284341   68.513373
# std      8.637688   23.414214    6.857123    0.116186    0.705587   28.212221
# min      0.006320    0.000000    0.460000    0.385000    3.561000    2.900000
# 25%      0.081990    0.000000    5.190000    0.449000    5.884000   45.000000
# 50%      0.261690    0.000000    9.690000    0.538000    6.208000   77.700000
# 75%      3.693110   12.500000   18.100000    0.624000    6.625000   94.000000
# max     88.976200  100.000000   27.740000    0.871000    8.780000  100.000000
#
#               dis         rad         tax     ptratio           b       lstat  \
# count  501.000000  501.000000  501.000000  501.000000  501.000000  501.000000
# mean     3.786423    9.596806  409.143713   18.453493  356.298523   12.643752
# ...

# %%
def adjust(val, irq, q1, q3):
    high = q3 + irq * 1.5
    low = q1 - irq * 1.5

    if(val > high):
        return high
    elif (val < low):
        return low
    else:
        return val

def remove_outlier(feature):
    q1 = df[feature].quantile(0.25)
    q3 = df[feature].quantile(0.75)

    irq = q3 - q1

    df[feature] = [adjust(i, irq, q1, q3) for i in df[feature]]

remove_outlier("crim")
remove_outlier("zn")
remove_outlier("rm")
remove_outlier("dis")
remove_outlier("b")
remove_outlier("ptratio")
remove_outlier("lstat")

# %%
plt.figure(figsize=(12,12))
plt.subplot(3, 4,1)
sns.boxplot(x = df["crim"])
plt.subplot(3, 4,2)
sns.boxplot(x = df["zn"])
plt.subplot(3, 4,3)
sns.boxplot(x = df["indus"])
plt.subplot(3, 4,4)
sns.boxplot(x = df["nox"])
plt.subplot(3, 4,5)
sns.boxplot(x = df["rm"])
plt.subplot(3, 4,6)
sns.boxplot(x = df["age"])
plt.subplot(3, 4,7)
sns.boxplot(x = df["dis"])
plt.subplot(3, 4,8)
sns.boxplot(x = df["rad"])
plt.subplot(3, 4,9)
sns.boxplot(x = df["tax"])
plt.subplot(3, 4,10)
sns.boxplot(x = df["ptratio"])
plt.subplot(3, 4,11)
sns.boxplot(x = df["b"])
plt.subplot(3, 4,12)
sns.boxplot(x = df["lstat"])
plt.show()

# %% [markdown]
# ## Spliting the Data

# %%
x = df.drop(["medv"], axis=1).values
y = df["medv"].values

x
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]])

# %%
y
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 18.9,
#        21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6, 15.2,
#        14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2, 13.1,
#        13.5, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7, 21.2, 19.3,
#        20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9, 35.4, 24.7,
#        31.6, 23.3, 19.6, 18.7, 16. , 22.2, 33. , 23.5, 19.4, 22. , 17.4,
#        20.9, 24.2, 21.7, 22.8, 23.4, 24.1, 21.4, 20. , 20.8, 21.2, 20.3,
#        28. , 23.9, 24.8, 22.9, 23.9, 26.6, 22.5, 22.2, 23.6, 28.7, 22.6,
#        22. , 22.9, 25. , 20.6, 28.4, 38.7, 43.8, 33.2, 27.5, 26.5, 18.6,
#        19.3, 20.1, 19.5, 19.5, 20.4, 19.8, 19.4, 21.7, 22.8, 18.8, 18.7,
#        18.5, 18.3, 21.2, 19.2, 20.4, 19.3, 22. , 20.3, 20.5, 17.3, 18.8,
#        21.4, 15.7, 16.2, 18. , 14.3, 19.2, 19.6, 23. , 18.4, 15.6, 17.4,
#        17.1, 13.3, 17.8, 14. , 14.4, 13.4, 15.6, 11.8, 13.8, 15.6, 14.6,
# ...

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

x_train.shape, y_train.shape
# Out:
# ((350, 12), (350,))

# %%
x_test.shape, y_test.shape
# Out:
# ((151, 12), (151,))

# %% [markdown]
# ## Preprocessing

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

x_test
# Out:
# array([[ 1.96995821, -0.59906291,  0.97371374, ...,  0.83792613,
#         -2.06535191,  0.12757196],
#        [-0.67462408, -0.59906291,  0.20929265, ...,  0.1439504 ,
#         -0.46670378, -0.06984109],
#        [ 1.96995821, -0.59906291,  0.97371374, ...,  0.83792613,
#          0.77254179,  0.69077978],
#        ...,
#        [-0.47377021,  1.02206027, -1.0758631 , ..., -2.4006273 ,
#          0.08839718,  0.33950068],
#        [ 1.96995821, -0.59906291,  0.97371374, ...,  0.83792613,
#         -2.06535191,  1.5704291 ],
#        [-0.6956674 , -0.59906291, -1.33550518, ...,  0.1439504 ,
#          0.62430157, -1.05110006]])

# %% [markdown]
# ## Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor()

model.fit(x_train, y_train)

y_pred = model.predict(x_test)

y_pred
# Out:
# array([19.6, 21. ,  9.6, 25.3, 20.1,  9.7, 11.5, 19.4, 20.5, 16.4, 21.7,
#        28.5, 14.4, 23.6, 13.3, 10.5, 23.6, 23. , 23.8, 10.2, 19. , 19.9,
#        22.9, 18.6, 22.6, 14.1, 22. , 22.9, 19.5, 20.4, 50. , 33.2, 16.1,
#        26.7, 31.5, 21.1, 12.1, 25.3, 19.3, 20. ,  9.7, 48.5, 13.3, 33.1,
#        13.3, 27.9, 29.4, 21.7, 17. , 17.2, 20.8, 23.3, 14.8, 11.8, 32.2,
#        31.1, 15.6, 19.3, 16.5, 26.2, 21.2, 39.8, 19.8, 13.3, 22.2, 35.1,
#        16.4, 16.5, 24.8, 11.5, 19.6, 22.5, 42.3, 24.5, 22.1, 22.7, 39.8,
#        22.1, 20. , 10.2, 25.3, 32.5, 19.9, 22.3, 25. , 29.1, 21.2, 11.7,
#        22.5, 50. ,  8.8, 13.3, 16.4, 23.7, 10.5, 24.7, 33.2, 21. , 10.5,
#        22.1, 24.7, 11.5, 17.2, 21.2, 20.4, 22.9, 36.1, 23.9, 20.4, 19.1,
#        15.6, 11.8, 20.4, 17.5, 19. , 19.7, 33.1, 20.8, 19.4, 20.8, 42.8,
#        23.9, 24.8, 22.1, 22. , 37.6, 19.1, 21.7, 23. , 22.2, 19. , 19.8,
#        15.2, 36.5, 15.6, 20.4, 36.5, 13.8, 18.5, 20.7, 22. , 20.8, 23.2,
# ...

# %%
y_test
# Out:
# array([23.1, 20. , 10.4, 27. , 19.8,  5.6, 12.3, 18. , 21.7, 12.7, 18.9,
#        34.9, 17.9, 22.2,  8.1,  8.3, 22.4, 14.5, 23.1,  7. , 19.7, 18.3,
#        22. , 19.9, 20.3, 19.1, 23.9, 23.3, 19.5, 19. , 27.9, 32.7, 14.9,
#        29.9, 34.7, 20.6,  7.2, 23.4, 23.7, 19.4, 12.8, 38.7, 13.6, 37. ,
#        13.5, 28. , 24. , 21.7, 14.2, 14.5, 21.4, 32. , 17.4,  7.5, 34.6,
#        31.6, 19.4, 18.2, 20. , 23.9, 16.8, 50. , 19.3,  7. , 24.8, 26.6,
#        13.5, 14.4, 23.7,  8.5, 21.7, 17.2, 46. , 28.6, 20.4, 20.3, 35.2,
#        22.8, 17.7, 23.1, 23.3, 26.6, 21.8, 24.6, 23. , 25. , 29.6, 16.7,
#        19.8, 50. ,  7.4, 14.6, 14.9, 22.6,  8.7, 18.6, 28.7, 21.2, 10.8,
#        23.1, 21.9, 23.2, 13.6, 22.2, 18.5, 23.3, 33.4, 29. , 19.5, 17.1,
#        13.4,  9.5, 18.7, 16.6, 19.9, 20.1, 29.6, 22.2, 20.3, 21.2, 50. ,
#        36.2, 24.6, 24.3, 25.1, 41.7, 13.4, 24.4, 19.2, 20.7, 13.2, 19.2,
#        16.7, 33.2, 13.8, 19.6, 30.3, 13.9, 20.2, 21.1, 20.9, 28.1, 21.2,
# ...

# %% [markdown]
# ## Error Calculation

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(y_test, y_pred)
# Out:
# 17.5953642384106

# %% [markdown]
# ## Visualization

# %%
plt.plot(x_test, y_test,"+", color = "green", label="Actual Data")
plt.plot(x_test, y_pred,".", color = "red", label="Predicted Data")
plt.title("Predicted VS Actual Data")
plt.show()

# %% [markdown]
# Predicted data with respect to age

# %%
sns.scatterplot(x = x_test[:,5], y=y_pred)
sns.scatterplot(x = x_test[:,5], y=y_test)
# Out:
# <Axes: >

# %% [markdown]
# ## Random Forest Implementation

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(n_estimators=500)

model.fit(x_train, y_train)

y_pred = model.predict(x_test)

y_test
# Out:
# array([23.1, 20. , 10.4, 27. , 19.8,  5.6, 12.3, 18. , 21.7, 12.7, 18.9,
#        34.9, 17.9, 22.2,  8.1,  8.3, 22.4, 14.5, 23.1,  7. , 19.7, 18.3,
#        22. , 19.9, 20.3, 19.1, 23.9, 23.3, 19.5, 19. , 27.9, 32.7, 14.9,
#        29.9, 34.7, 20.6,  7.2, 23.4, 23.7, 19.4, 12.8, 38.7, 13.6, 37. ,
#        13.5, 28. , 24. , 21.7, 14.2, 14.5, 21.4, 32. , 17.4,  7.5, 34.6,
#        31.6, 19.4, 18.2, 20. , 23.9, 16.8, 50. , 19.3,  7. , 24.8, 26.6,
#        13.5, 14.4, 23.7,  8.5, 21.7, 17.2, 46. , 28.6, 20.4, 20.3, 35.2,
#        22.8, 17.7, 23.1, 23.3, 26.6, 21.8, 24.6, 23. , 25. , 29.6, 16.7,
#        19.8, 50. ,  7.4, 14.6, 14.9, 22.6,  8.7, 18.6, 28.7, 21.2, 10.8,
#        23.1, 21.9, 23.2, 13.6, 22.2, 18.5, 23.3, 33.4, 29. , 19.5, 17.1,
#        13.4,  9.5, 18.7, 16.6, 19.9, 20.1, 29.6, 22.2, 20.3, 21.2, 50. ,
#        36.2, 24.6, 24.3, 25.1, 41.7, 13.4, 24.4, 19.2, 20.7, 13.2, 19.2,
#        16.7, 33.2, 13.8, 19.6, 30.3, 13.9, 20.2, 21.1, 20.9, 28.1, 21.2,
# ...

# %%
y_pred
# Out:
# array([18.679 , 20.625 , 19.0788, 28.3734, 20.3932,  9.6994, 10.9252,
#        17.417 , 22.78  , 15.4392, 19.7754, 32.8098, 14.1738, 22.5296,
#        15.5194, 10.4574, 24.0804, 19.4384, 23.8378,  9.2464, 17.5832,
#        20.896 , 21.0502, 20.0354, 22.061 , 14.674 , 28.6134, 21.6978,
#        19.4434, 21.784 , 26.423 , 33.0236, 14.3964, 27.127 , 35.2214,
#        21.1678, 10.5436, 24.3038, 18.3838, 20.4634, 10.1384, 44.4684,
#        17.1914, 31.835 , 14.4436, 27.2646, 28.1572, 20.9278, 14.3492,
#        15.9942, 23.0338, 26.067 , 16.7522, 10.6756, 32.7192, 31.454 ,
#        15.9028, 19.831 , 18.817 , 25.0482, 20.9148, 43.309 , 21.3924,
#        15.4662, 23.3572, 31.327 , 15.431 , 18.086 , 24.7492, 12.8246,
#        20.8136, 19.3234, 46.4694, 26.0684, 22.915 , 22.1672, 42.5024,
#        23.3292, 18.5424, 18.3276, 28.5188, 27.2416, 20.5212, 23.4064,
#        24.4606, 24.5536, 23.2418, 13.19  , 19.494 , 45.521 ,  8.876 ,
# ...

# %%
mean_squared_error(y_pred, y_test)
# Out:
# 9.616492037615933

# %% [markdown]
# ## Visualization

# %%
plt.plot(x_test, y_test, "+",color="blue")
plt.plot(x_test, y_pred, ".",color="red")
plt.title("Random Forest Prediction")
# Out:
# Text(0.5, 1.0, 'Random Forest Prediction')
